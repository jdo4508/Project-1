# %%
import pandas as pd
import numpy as np

# %%
census_data = pd.read_csv("census_pd.csv")
income = census_data[["County FIPS", "Household Income"]]
income
income.to_csv("income.csv", header=False, index=False)
# census_data

# %%
census = pd.read_csv("census_state.csv")
income_state = census[["State Name", "Household Income"]]

income_state.to_csv("income_state.csv", header=False, index=False)
census
# Out:
#               State Name  State FIPS  County FIPS  Household Income  \
# 0                Alabama          67         4489         2698184.0
# 1                 Alaska          58         4340         1926338.0
# 2                Arizona          60          208          687250.0
# 3               Arkansas         375         5625         2926881.0
# 4             California         348         3364         3540712.0
# 5               Colorado         512         3983         3478628.0
# 6            Connecticut          72           64          595968.0
# 7               Delaware          30            9          183884.0
# 8   District of Columbia          11            1           77649.0
# 9                Florida         804         4550         3158670.0
# 10               Georgia        2067        25677         6879737.0
# 11                Hawaii          75           25          343315.0
# 12                 Idaho         704         1936         2031565.0
# ...
