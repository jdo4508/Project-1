# %%
import pandas as pd
import numpy as np

# %%
census_data = pd.read_csv("census_pd.csv")
income = census_data[["County FIPS", "Household Income"]]
income
income.to_csv("income.csv", header=False, index=False)
# census_data

# %%
census = pd.read_csv("census_state.csv")
income_state = census[["State Name", "Household Income"]]

income_state.to_csv("income_state.csv", header=False, index=False)
census.head()
# Out:
#    State Name  State FIPS  County FIPS  Household Income  Median Age  \
# 0     Alabama          67         4489         2698184.0      2710.1
# 1      Alaska          58         4340         1926338.0      1071.4
# 2     Arizona          60          208          687250.0       599.0
# 3    Arkansas         375         5625         2926881.0      3099.8
# 4  California         348         3364         3540712.0      2289.5
#
#    Median Male Age  Median Female Age       White  Black or African American  \
# 0           2604.3             2812.8   3317702.0                  1287167.0
# 1           1090.5             1048.6    481971.0                    23702.0
# 2            583.6              616.9   5277661.0                   292831.0
# 3           2996.6             3200.9   2302141.0                   459969.0
# 4           2230.3             2366.7  23607242.0                  2263222.0
#
#    American Indian and Alaska Native  ...  \
# ...

# %%
final = pd.read_csv("final_df.csv")
population = final["Household Income"]
population = pd.DataFrame(final["Household Income"])
population = population.rename(columns= {"Household Income":"Population"})
population.to_csv("population.csv", index=False)

# %%
income_state["Household Income"] = population["Population"].astype(float)
# del income_state["Household Income"]

income_state.to_csv("incomeav.csv", index=False, header=False)
income_state.head()
# Out:
# C:\Users\cfhor\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    State Name  Household Income
# 0     Alabama          40271.40
# 1      Alaska          66425.45
# 2     Arizona          45816.67
# 3    Arkansas          39025.08
# 4  California          61046.76

# %%
final = pd.read_csv("final_df.csv")
final.head()
# Out:
#    State Name  Household Income  Median Age  Median Male Age  \
# 0     Alabama          40271.40       40.45            38.87
# 1      Alaska          66425.45       36.94            37.60
# 2     Arizona          45816.67       39.93            38.91
# 3    Arkansas          39025.08       41.33            39.95
# 4  California          61046.76       39.47            38.45
#
#    Median Female Age  No College Degree  No College Degree Percentage  \
# 0              41.98          1567420.0                      0.647095
# 1              36.16           229333.0                      0.617160
# 2              41.13          1960152.0                      0.596793
# 3              42.68          1017698.0                      0.689379
# 4              40.81         10129401.0                      0.548433
#
#    Associates or Bachelors Degree  Associates or Bachelors Degree Percentage  \
# 0                        771175.0                                   0.318372
# ...
